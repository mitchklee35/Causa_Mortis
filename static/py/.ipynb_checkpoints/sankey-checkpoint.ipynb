# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.stats import linregress
import json as json
from pandas.io.json import json_normalize
import sqlite3
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
import os

# %%
filepath = os.path.join("../data/cause_of_death.json")
with open(filepath) as jsonfile:
    CODjson = json.load(jsonfile)

# %%
CODdata = CODjson['data']
COD_df = pd.DataFrame(CODdata)
COD_df.head(5)
# Out:
#                     0                                     1  2           3  \
# 0  row-4ziw_fype-q93g  00000000-0000-0000-84F0-BE0C2CBEC77B  0  1571926784
# 1  row-mf82_5qce.78c2  00000000-0000-0000-F702-31C8D4A1E5BE  0  1571926784
# 2  row-7frh~9yb6-q2q4  00000000-0000-0000-6FE5-1E0821A4276B  0  1571926784
# 3  row-urf6.ayyb~8p5q  00000000-0000-0000-26D0-367B1AF824D1  0  1571926784
# 4  row-74k2-qi6f~77p7  00000000-0000-0000-C87C-FAD80FEC2E12  0  1571926784
#
#       4           5     6    7     8  \
# 0  None  1571926784  None  { }  2017
# 1  None  1571926784  None  { }  2017
# 2  None  1571926784  None  { }  2017
# 3  None  1571926784  None  { }  2017
# 4  None  1571926784  None  { }  2017
#
#                                                    9                      10  \
# 0  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 1  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 2  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 3  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 4  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
#
#               11      12    13
# 0  United States  169936  49.4
# 1        Alabama    2703  53.8
# 2         Alaska     436  63.7
# 3        Arizona    4184  56.2
# 4       Arkansas    1625  51.8

# %%
# json file labels
# 0 - 'sid'
# 1 - 'id'
# 2 - 'position'
# 3 - 'created_at'
# *4 - 'created_meta' - null values
# 5 - 'updated_at'
# *6 - 'meta_data' - null values
# *7 - 'meta' - only contains '{}'
# 8 - 'year'
# 9 - '113 Cause Name'
# 10 - 'Cause Name'
# 11 - 'State'
# 12 - 'Deaths'
# 13 - 'Age-Adjusted Death Rate'

sid = COD_df[0]
cod_id = COD_df[1]
position = COD_df[2]
created_at = COD_df[3]
updated_at = COD_df[5]
year = COD_df[8]
exp_cause_name = COD_df[9]
cause_name = COD_df[10]
state = COD_df[11]
deaths = COD_df[12]
Age_Adj_DR = COD_df[13]

sankey_df = pd.DataFrame({"year": year,
                            "Cause Name": cause_name,
                            "deaths": deaths,
                            "state": state
                            })
sankey_df=sankey_df[state=="United States"]
sankey_df.head(50)
#jsonify(sankey_df)
# Out:
#       year               Cause Name   deaths          state
# 0     2017   Unintentional injuries   169936  United States
# 52    2017               All causes  2813503  United States
# 104   2017      Alzheimer's disease   121404  United States
# 156   2017                   Stroke   146383  United States
# 208   2017                     CLRD   160201  United States
# 260   2017                 Diabetes    83564  United States
# 312   2017            Heart disease   647457  United States
# 364   2017  Influenza and pneumonia    55672  United States
# 416   2017                  Suicide    47173  United States
# 468   2017                   Cancer   599108  United States
# 520   2017           Kidney disease    50633  United States
# 623   2016   Unintentional injuries   161374  United States
# 668   2016               All causes  2744248  United States
# 720   2016      Alzheimer's disease   116103  United States
# 772   2016                   Stroke   142142  United States
# 824   2016                     CLRD   154596  United States
# 876   2016                 Diabetes    80058  United States
# 928   2016            Heart disease   635260  United States
# 980   2016  Influenza and pneumonia    51537  United States
# 1032  2016                  Suicide    44965  United States
# 1084  2016                   Cancer   598038  United States
# 1136  2016           Kidney disease    50046  United States
# 1188  2015   Unintentional injuries   146571  United States
# 1240  2015               All causes  2712630  United States
# 1292  2015      Alzheimer's disease   110561  United States
# 1344  2015                   Stroke   140323  United States
# 1396  2015                     CLRD   155041  United States
# 1448  2015                 Diabetes    79535  United States
# 1500  2015            Heart disease   633842  United States
# 1552  2015  Influenza and pneumonia    57062  United States
# 1604  2015                  Suicide    44193  United States
# 1656  2015                   Cancer   595930  United States
# 1708  2015           Kidney disease    49959  United States
# 1760  2014   Unintentional injuries   135928  United States
# 1812  2014               All causes  2626418  United States
# 1864  2014      Alzheimer's disease    93541  United States
# 1916  2014                   Stroke   133103  United States
# 1968  2014                     CLRD   147101  United States
# 2020  2014                 Diabetes    76488  United States
# 2072  2014            Heart disease   614348  United States
# 2124  2014  Influenza and pneumonia    55227  United States
# 2176  2014                  Suicide    42826  United States
# 2228  2014                   Cancer   591700  United States
# 2280  2014           Kidney disease    48146  United States
# 2332  2013   Unintentional injuries   130557  United States
# 2384  2013               All causes  2596993  United States
# 2436  2013      Alzheimer's disease    84767  United States
# 2488  2013                   Stroke   128978  United States
# 2540  2013                     CLRD   149205  United States
# 2592  2013                 Diabetes    75578  United States

# %%
grouped_sankey = sankey_df.groupby(["year","Cause Name"]).sum()
grouped_sankey.head()
# Out:
#                            deaths          state
# year Cause Name
# 1999 All causes           2391399  United States
#      Alzheimer's disease    44536  United States
#      CLRD                  124181  United States
#      Cancer                549838  United States
#      Diabetes               68399  United States

# %%
data =[]

for index, row in grouped_sankey.iterrows():
    data.append({"from": index[0], "to": index[1], "weight": row["deaths"]})

# %%
print(data)
# Out:
# [{'from': '1999', 'to': 'All causes', 'weight': '2391399'}, {'from': '1999', 'to': "Alzheimer's disease", 'weight': '44536'}, {'from': '1999', 'to': 'CLRD', 'weight': '124181'}, {'from': '1999', 'to': 'Cancer', 'weight': '549838'}, {'from': '1999', 'to': 'Diabetes', 'weight': '68399'}, {'from': '1999', 'to': 'Heart disease', 'weight': '725192'}, {'from': '1999', 'to': 'Influenza and pneumonia', 'weight': '63730'}, {'from': '1999', 'to': 'Kidney disease', 'weight': '35525'}, {'from': '1999', 'to': 'Stroke', 'weight': '167366'}, {'from': '1999', 'to': 'Suicide', 'weight': '29199'}, {'from': '1999', 'to': 'Unintentional injuries', 'weight': '97860'}, {'from': '2000', 'to': 'All causes', 'weight': '2403351'}, {'from': '2000', 'to': "Alzheimer's disease", 'weight': '49558'}, {'from': '2000', 'to': 'CLRD', 'weight': '122009'}, {'from': '2000', 'to': 'Cancer', 'weight': '553091'}, {'from': '2000', 'to': 'Diabetes', 'weight': '69301'}, {'from': '2000', 'to': 'Heart disease', 'weight': '710760'}, {'from': '2000', 'to': 'Influenza and pneumonia', 'weight': '65313'}, {'from': '2000', 'to': 'Kidney disease', 'weight': '37251'}, {'from': '2000', 'to': 'Stroke', 'weight': '167661'}, {'from': '2000', 'to': 'Suicide', 'weight': '29350'}, {'from': '2000', 'to': 'Unintentional injuries', 'weight': '97900'}, {'from': '2001', 'to': 'All causes', 'weight': '2416425'}, {'from': '2001', 'to': "Alzheimer's disease", 'weight': '53852'}, {'from': '2001', 'to': 'CLRD', 'weight': '123013'}, {'from': '2001', 'to': 'Cancer', 'weight': '553768'}, {'from': '2001', 'to': 'Diabetes', 'weight': '71372'}, {'from': '2001', 'to': 'Heart disease', 'weight': '700142'}, {'from': '2001', 'to': 'Influenza and pneumonia', 'weight': '62034'}, {'from': '2001', 'to': 'Kidney disease', 'weight': '39480'}, {'from': '2001', 'to': 'Stroke', 'weight': '163538'}, {'from': '2001', 'to': 'Suicide', 'weight': '30622'}, {'from': '2001', 'to': 'Unintentional injuries', 'weight': '101537'}, {'from': '2002', 'to': 'All causes', 'weight': '2443387'}, {'from': '2002', 'to': "Alzheimer's disease", 'weight': '58866'}, {'from': '2002', 'to': 'CLRD', 'weight': '124816'}, {'from': '2002', 'to': 'Cancer', 'weight': '557271'}, {'from': '2002', 'to': 'Diabetes', 'weight': '73249'}, {'from': '2002', 'to': 'Heart disease', 'weight': '696947'}, {'from': '2002', 'to': 'Influenza and pneumonia', 'weight': '65681'}, {'from': '2002', 'to': 'Kidney disease', 'weight': '40974'}, {'from': '2002', 'to': 'Stroke', 'weight': '162672'}, {'from': '2002', 'to': 'Suicide', 'weight': '31655'}, {'from': '2002', 'to': 'Unintentional injuries', 'weight': '106742'}, {'from': '2003', 'to': 'All causes', 'weight': '2448288'}, {'from': '2003', 'to': "Alzheimer's disease", 'weight': '63457'}, {'from': '2003', 'to': 'CLRD', 'weight': '126382'}, {'from': '2003', 'to': 'Cancer', 'weight': '556902'}, {'from': '2003', 'to': 'Diabetes', 'weight': '74219'}, {'from': '2003', 'to': 'Heart disease', 'weight': '685089'}, {'from': '2003', 'to': 'Influenza and pneumonia', 'weight': '65163'}, {'from': '2003', 'to': 'Kidney disease', 'weight': '42453'}, {'from': '2003', 'to': 'Stroke', 'weight': '157689'}, {'from': '2003', 'to': 'Suicide', 'weight': '31484'}, {'from': '2003', 'to': 'Unintentional injuries', 'weight': '109277'}, {'from': '2004', 'to': 'All causes', 'weight': '2397615'}, {'from': '2004', 'to': "Alzheimer's disease", 'weight': '65965'}, {'from': '2004', 'to': 'CLRD', 'weight': '121987'}, {'from': '2004', 'to': 'Cancer', 'weight': '553888'}, {'from': '2004', 'to': 'Diabetes', 'weight': '73138'}, {'from': '2004', 'to': 'Heart disease', 'weight': '652486'}, {'from': '2004', 'to': 'Influenza and pneumonia', 'weight': '59664'}, {'from': '2004', 'to': 'Kidney disease', 'weight': '42480'}, {'from': '2004', 'to': 'Stroke', 'weight': '150074'}, {'from': '2004', 'to': 'Suicide', 'weight': '32439'}, {'from': '2004', 'to': 'Unintentional injuries', 'weight': '112012'}, {'from': '2005', 'to': 'All causes', 'weight': '2448017'}, {'from ...
