# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.stats import linregress
import json as json
from pandas.io.json import json_normalize
import sqlite3
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
import os

# %%
filepath = os.path.join("../data/cause_of_death.json")
with open(filepath) as jsonfile:
    CODjson = json.load(jsonfile)

# %%
CODdata = CODjson['data']
COD_df = pd.DataFrame(CODdata)
COD_df.head(5)
# Out:
#                     0                                     1  2           3  \
# 0  row-4ziw_fype-q93g  00000000-0000-0000-84F0-BE0C2CBEC77B  0  1571926784
# 1  row-mf82_5qce.78c2  00000000-0000-0000-F702-31C8D4A1E5BE  0  1571926784
# 2  row-7frh~9yb6-q2q4  00000000-0000-0000-6FE5-1E0821A4276B  0  1571926784
# 3  row-urf6.ayyb~8p5q  00000000-0000-0000-26D0-367B1AF824D1  0  1571926784
# 4  row-74k2-qi6f~77p7  00000000-0000-0000-C87C-FAD80FEC2E12  0  1571926784
#
#       4           5     6    7     8  \
# 0  None  1571926784  None  { }  2017
# 1  None  1571926784  None  { }  2017
# 2  None  1571926784  None  { }  2017
# 3  None  1571926784  None  { }  2017
# 4  None  1571926784  None  { }  2017
#
#                                                    9                      10  \
# 0  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 1  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 2  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 3  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
# 4  Accidents (unintentional injuries) (V01-X59,Y8...  Unintentional injuries
#
#               11      12    13
# 0  United States  169936  49.4
# 1        Alabama    2703  53.8
# 2         Alaska     436  63.7
# 3        Arizona    4184  56.2
# 4       Arkansas    1625  51.8

# %%
# json file labels
# 0 - 'sid'
# 1 - 'id'
# 2 - 'position'
# 3 - 'created_at'
# *4 - 'created_meta' - null values
# 5 - 'updated_at'
# *6 - 'meta_data' - null values
# *7 - 'meta' - only contains '{}'
# 8 - 'year'
# 9 - '113 Cause Name'
# 10 - 'Cause Name'
# 11 - 'State'
# 12 - 'Deaths'
# 13 - 'Age-Adjusted Death Rate'

sid = COD_df[0]
cod_id = COD_df[1]
position = COD_df[2]
created_at = COD_df[3]
updated_at = COD_df[5]
year = COD_df[8]
exp_cause_name = COD_df[9]
cause_name = COD_df[10]
state = COD_df[11]
deaths = COD_df[12]
Age_Adj_DR = COD_df[13]

sankey_df = pd.DataFrame.groupby({"113 Cause Name": exp_cause_name,
                            "Cause Name": cause_name,
                            "deaths": deaths
                            })
sankey_df.to_json()
# Out:
# '{"113 Cause Name":{"0":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","1":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","2":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","3":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","4":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","5":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","6":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","7":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","8":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","9":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","10":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","11":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","12":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","13":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","14":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","15":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","16":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","17":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","18":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","19":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","20":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","21":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","22":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","23":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","24":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","25":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","26":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","27":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","28":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","29":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","30":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","31":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","32":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","33":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","34":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","35":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","36":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","37":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","38":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","39":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","40":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","41":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","42":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","43":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","44":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","45":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","46":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","47":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","48":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","49":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","50":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","51":"Accidents (unintentional injuries) (V01-X59,Y85-Y86)","52":"All Causes","53":"All Causes","54":"All Causes","55":"All Causes","56":"All Causes","57":"All Causes","58":"All Causes","59":"All Causes","60":"All Causes","61":"All Causes","62":"All Causes","63":"All Causes","64":"All Causes","65":"All Causes","66":"All Causes","67":"All Causes","68":"All Causes","69":"All Causes","70":"All Causes","71":"All Causes","72":"All Causes","73":"All Causes","74":"All Causes","75":"All Causes","76":"All Causes","77":"All Causes","78":"All Causes","79":"All Causes","80":"All Causes","81":"All Causes","82":"All Causes","83":"All Causes","84":"All Causes","85":"All Causes","86":"All Causes","87":"All Causes","88":"All Causes","89":"All Causes","90":"All Causes","91":"All Causes","92":"All Causes","93":"All Causes","94":"All Causes","95":"All Causes","96":"All Causes","97":"All Causes","98":"All Causes","99":"All Causes","100": ...
