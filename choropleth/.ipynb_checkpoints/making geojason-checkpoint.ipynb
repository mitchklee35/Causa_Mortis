# %%
import json
import sqlite3
import pandas as pd

# %%
#import json file

# %%
with open('states.json') as f:
  data = json.load(f)

# %%
#import csv file

# %%
csvfile = pd.read_csv("clean.csv")
csvfile=csvfile.groupby("state").sum()["deaths"]

# %%
# reset the index of csv file 
csv_reset_index = csvfile.reset_index()
csv_reset_index
# Out:
#                    state    deaths
# 0                Alabama   1603535
# 1                 Alaska    117890
# 2                Arizona   1572443
# 3               Arkansas    987455
# 4             California   8169513
# 5               Colorado   1039435
# 6            Connecticut    981027
# 7               Delaware    255015
# 8   District of Columbia    168907
# 9                Florida   5868231
# 10               Georgia   2326265
# 11                Hawaii    320652
# 12                 Idaho    375595
# 13              Illinois   3489953
# 14               Indiana   1934641
# 15                  Iowa    954486
# 16                Kansas    831840
# 17              Kentucky   1423885
# 18             Louisiana   1409567
# 19                 Maine    433412
# 20              Maryland   1469677
# 21         Massachusetts   1812189
# 22              Michigan   3011369
# 23             Minnesota   1288025
# 24           Mississippi    992097
# 25              Missouri   1905549
# 26               Montana    294784
# 27              Nebraska    513032
# 28                Nevada    652604
# 29         New Hampshire    353884
# 30            New Jersey   2397044
# 31            New Mexico    521279
# 32              New York   5161056
# 33        North Carolina   2608123
# 34          North Dakota    202091
# 35                  Ohio   3716207
# 36              Oklahoma   1243157
# 37                Oregon   1064013
# 38          Pennsylvania   4304492
# 39          Rhode Island    327640
# 40        South Carolina   1364864
# 41          South Dakota    244178
# 42             Tennessee   2012251
# 43                 Texas   5535028
# 44         United States  84009152
# 45                  Utah    472567
# 46               Vermont    179348
# 47              Virginia   1989346
# 48            Washington   1635078
# 49         West Virginia    721988
# 50             Wisconsin   1607291
# 51               Wyoming    145154

# %%
# csv_reset_index.loc["Wyoming"]
# csvfile.loc["Wyoming"]
# csvfile.loc[csvfile['state'] == 'Wyoming']
# csvfile.loc[csvfile['deaths'].isin(Wyoming)]
# csvfile.loc['Wisconsin']
csv_reset_index['state']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# 34            North Dakota
# 35                    Ohio
# 36                Oklahoma
# 37                  Oregon
# 38            Pennsylvania
# 39            Rhode Island
# 40          South Carolina
# 41            South Dakota
# 42               Tennessee
# 43                   Texas
# 44           United States
# 45                    Utah
# 46                 Vermont
# 47                Virginia
# 48              Washington
# 49           West Virginia
# 50               Wisconsin
# 51                 Wyoming
# Name: state, dtype: object

# %%
#loop trough all of the json file, if the state in json file is the same in csvfile, replace denisty with deaths value!Else return zero 


with open('states.json') as f:
    data = json.load(f)
    for i in data["features"]:
        state_json =i["properties"]["name"]                        
        if (csv_reset_index['state'] == 'state_json').any():
#             ["properties"]["density"]= csvfile.loc[state_json]
            i["properties"]["density"]=csvfile.loc[state_json]
        else:
            i["properties"]["density"]= 0
        



# csvfile.loc[state_json]
# i["properties"]["density"]''
# data["features"][0]["properties"]["density"]
# csvfile.loc[state_json]
csvfile.loc["state_json"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Puerto Rico'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-6f58abdb1bc7> in <module>
#       7         state_json =i["properties"]["name"]
#       8 #         if (csv_reset_index['state'] == 'state_json').any():
# ----> 9 abc = csvfile.loc[state_json]
#      10 #             ["properties"]["density"]= csvfile.loc["state_json"]
#      11 #     i["properties"]["density"]=csvfile.loc[state_json]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     618             # but will fail when the index is not present
#     619             # see GH5667
# --> 620             return self.obj._xs(label, axis=axis)
#     621         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     622             raise IndexingError("no slices here, handle elsewhere")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Puerto Rico'

# %%
#export json file 
with open('data.geojson', 'w') as outfile:
    json.dump(data, outfile)

# %%
with open("sample.json", "w") as outfile:
    json.dump(dictionary, outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-389354c905f7> in <module>
#       1 with open("sample.json", "w") as outfile:
# ----> 2     json.dump(dictionary, outfile)
#
# NameError: name 'dictionary' is not defined
